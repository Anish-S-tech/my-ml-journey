# %% [markdown]
# <a href="https://colab.research.google.com/github/Anish-S-tech/my-ml-journey/blob/main/Implementation_of_confusion_matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# confusion matrix for binary classification (2 classes only)

import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %%
actual    = np.array(
  ['Dog','Dog','Dog','Not Dog','Dog','Not Dog','Dog','Dog','Not Dog','Not Dog'])
predicted = np.array(
  ['Dog','Not Dog','Dog','Not Dog','Dog','Dog','Dog','Dog','Not Dog','Not Dog'])

# %%
# Precision and recall
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import precision_score, recall_score

encoder = LabelEncoder()

actual = encoder.fit_transform(actual)
predicted = encoder.fit_transform(predicted)

precision1 = precision_score(actual,predicted)
recall1 = recall_score(actual,predicted)

print(f"Precision: {precision1}")
print(f"Recall: {recall1}")
# Out:
# Precision: 0.75
# Recall: 0.75

# %%
confusion_mat = confusion_matrix(actual,predicted)

# %%
sns.heatmap(confusion_mat, fmt='d', cmap="Blues", annot=True)
# Out:
# <Axes: >

# %%
print(classification_report(actual,predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83         6
#            1       0.75      0.75      0.75         4
#
#     accuracy                           0.80        10
#    macro avg       0.79      0.79      0.79        10
# weighted avg       0.80      0.80      0.80        10

# %%
# Confusion matrix for multiple classes - (3 or more classes)
from sklearn.metrics import ConfusionMatrixDisplay

# %%
y_true = ['Cat'] * 10 + ['Dog'] * 12 + ['Horse'] * 10
y_pred = ['Cat'] * 8 + ['Dog'] + ['Horse'] + ['Cat'] * 2 + ['Dog'] * 10 + ['Horse'] * 8 + ['Dog'] * 2
classes = ['Cat', 'Dog', 'Horse']

# %%
print(y_true)
print(y_pred)
print(classes)
# Out:
# ['Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Dog', 'Dog', 'Dog', 'Dog', 'Dog', 'Dog', 'Dog', 'Dog', 'Dog', 'Dog', 'Dog', 'Dog', 'Horse', 'Horse', 'Horse', 'Horse', 'Horse', 'Horse', 'Horse', 'Horse', 'Horse', 'Horse']
# ['Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Dog', 'Horse', 'Cat', 'Cat', 'Dog', 'Dog', 'Dog', 'Dog', 'Dog', 'Dog', 'Dog', 'Dog', 'Dog', 'Dog', 'Horse', 'Horse', 'Horse', 'Horse', 'Horse', 'Horse', 'Horse', 'Horse', 'Dog', 'Dog']
# ['Cat', 'Dog', 'Horse']

# %%
confusion = confusion_matrix(y_true,y_pred)

# %%
# one way - Using seaborn's heatmap

sns.heatmap(confusion,fmt='d', cmap="Blues", annot = True)
# Out:
# <Axes: >

# %%
# another way - Using matplotlib + sklearn (ConfusionMatrixDisplay)

confusion = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=confusion)
disp.plot(cmap="Blues")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import precision_score, recall_score

encoder = LabelEncoder()

y_true = encoder.fit_transform(y_true)
y_pred = encoder.fit_transform(y_pred)

precision2 = precision_score(y_true,y_pred,average='macro')
recall2 = recall_score(y_true,y_pred, average='micro')

print(f"Precision: {precision2}")
print(f"Recall: {recall2}")
# Out:
# Precision: 0.8193732193732194
# Recall: 0.8125

# %%
# F1 score

from sklearn.metrics import f1_score

f1_none = f1_score(y_true,y_pred,average=None)
f1_micro = f1_score(y_true,y_pred,average="micro")
f1_macro = f1_score(y_true,y_pred,average="macro")
f1_weighted = f1_score(y_true,y_pred,average="weighted")

print(f"f1 score per class: {f1_none}")
print(f"Micro-average f1 score: {f1_micro}")
print(f"Macro-average f1 score: {f1_macro}")
print(f"Weighted-average f1 score: {f1_weighted}")
# Out:
# f1 score per class: [0.8        0.8        0.84210526]
# Micro-average f1 score: 0.8125
# Macro-average f1 score: 0.8140350877192982
# Weighted-average f1 score: 0.8131578947368421
