# %% [markdown]
# <a href="https://colab.research.google.com/github/Anish-S-tech/my-ml-journey/blob/main/Implementing_multiple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Importing necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_california_housing
from sklearn.linear_model import LinearRegression

# %%
# 2. Loading the dataset

california_housing = fetch_california_housing()
X = pd.DataFrame(california_housing.data, columns = california_housing.feature_names)
y = pd.Series(california_housing.target)

# %%
# 3. Selecting features for training (multiple features here)

X = X[['MedInc', 'AveRooms']]

# %%
# 4. Train-Test split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=42)

# %%
# 5. Initializing and training the model

model = LinearRegression()
model.fit(X_train,y_train)

# %%
# 6. Making predictions

y_pred = model.predict(X_test)

# %%
display(y_pred)
